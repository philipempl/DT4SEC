# %% [markdown]
# *kursiver Text*# Digital Twin Survey

# %% [markdown]
# **NOTE:**
# You will be prompted to upload a text file from your Google Drive.
#
# If you would like to use the file that was used in this example, copy it from this link to your Google Drive:
#
# https://github.com/gal-a/blog/blob/master/docs/notebooks/nlp/data/quotes.txt

# %%
# Setup
# !pip install -q wordcloud
import wordcloud

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('genesis')
nltk.download('averaged_perceptron_tagger') 
from nltk.collocations import *
import pandas as pd
import matplotlib.pyplot as plt
import io
import unicodedata
import numpy as np
import re
import string
# Constants
# POS (Parts Of Speech) for: nouns, adjectives, verbs and adverbs
DI_POS_TYPES = {'NN':'n', 'JJ':'a', 'VB':'v', 'RB':'r'} 
POS_TYPES = list(DI_POS_TYPES.keys())

# Constraints on tokens
MIN_STR_LEN = 3
RE_VALID = '[a-zA-Z]'
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package genesis to /root/nltk_data...
# [nltk_data]   Unzipping corpora/genesis.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Load the corpus file from Google Drive

# %%
# Upload from google drive
from google.colab import files
uploaded = files.upload()
print("len(uploaded.keys():", len(uploaded.keys()))

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))

# Get coding list
df_references = pd.read_csv(io.StringIO(uploaded['coding.txt'].decode('utf-8')), sep=',', keep_default_na=False)
  
# Display
print("references:")
print(df_references.head().to_string())
# Out:
#      <input type="file" id="files-7d6919a8-b6f5-4b80-8d5e-24954c4bbd5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d6919a8-b6f5-4b80-8d5e-24954c4bbd5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving coding.txt to coding (1).txt
# len(uploaded.keys(): 1
# User uploaded file "coding.txt" with length 119457 bytes
# references:
#              Key Relevance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Contribution                                                                                                                                                                                                                    Definition                                                                                                                                                                                                                                                                           Application_Reason        Industry                                    Scenario Location                                   Asset                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Data                 Communication_Type Level_of_Integration     Protocols     Tools                                                                        Operation_Mode                                                                                                                                                                                 Creation Architecture                                                                                                                                   Challenges_Future
# 0   Akbarian2020      HIGH                                                                                                                                                                                                                                          In this paper, we propose implementing digital twins that have been equipped with an intrusion detection algorithm. Our novel algorithm is able to detect attacks in a timely manner and aslo diagnose the type of attack by classficiation of different types of attacks.                                                                                                                                                                              mirror the internal behaviour of physical systems                                                                                                                                                              So using this virtual environment for security tests instead of the real system prevents any interference with the live systems        Industry                         Intrusion Detection    Cloud                             ICS Network                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  N/A                   DIGITAL_PHYSICAL         DIGITAL_TWIN           N/A  Simulink  Kalman Filter (detection), Particle Swarm Optimization (noise), SVM (classification)                                                                                    Simulation model of the real system that has been obtained easily by system identification algorithms          YES                                                                                                                                                 N/A
# 1  Almeaibed2021    MEDIUM                                                                                                                                                             This article aims to identify a standard framework for vehicular digital twins that facilitate data collection, data processing, and analytics phases. To demonstrate the effectiveness of the proposed approach, a case study for vehicle follower model is analyzed when radar sensor measurements are manipulated in an attempt to cause a collision.                   In the perspective of autonomous vehicles, a digital twinrefers to the efforts placed in the design and implementation of processes needed to enhance the safety, security, and privacy of driverless cars                                                                                                                                                                                                                                    Monitoring, reduces complexity, data analytics, connection  Mobility (Car)  Security Testing & Generation of Knowledge    Cloud                                Car Data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Sensor data, weather data, GPS                   DIGITAL_PHYSICAL         DIGITAL_TWIN           N/A       N/A                                                                            Simulation                                                                                                                                                                                      N/A          YES                                                                                                               more security and privacy of car data
# 2    Anthony2020       LOW                                                                               This paper aims to present the development of a digital twin of the commercial greenhouse production process as a part of the recently launched EUDP funded project Greenhouse Industry 4.0 in Denmark. This digital twin allows using big data and the Internet of Things to optimise the greenhouse production process and communicate with other digital twins representing essential areas in the greenhouse (climate and energy).  DTs have been proved usefully in  optimising systems based on collected data and how a  system responds to changes in setting. This can help  stakeholders realise unexploited potentials and improve  operational security   Deploying the DT concept support co-optimization of the production schedule, energy  consumption, and labour cost, by considering influential factors including production deadlines, quality grading, heating, artificial lighting, energy prices (gas electricity), and weather forecasts        Industry                                         N/A    Cloud             Production, Climate, Energy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Sensor data  DIGITAL_DIGITAL, DIGITAL_PHYSICAl         DIGITAL_TWIN           N/A  Anylogic                                                                            Simulation  generic multi-agent simulation model of the greenhouse production flow that includes all production steps from the delivery of initial seedlings until the shipment of the final plants           NO                                                                                                                                                 N/A
# 3    Assenza2020       LOW                                                                                                                                                                                                                                                                                                                                 This paper collects the contributions to the industry dis-semination session within the 14th International Conference on Critical Information Infrastructures Security (CRITIS 2019)                                                                                        The simulations can also be fast-forwarded to foresee the e?ects of updates, repairs, preventive maintenance, and even future threats.                                                                                                                                                                                                                                                          Simulation, not interrupting system          CRITIS                         Intrusion Detection      N/A                                     N/A                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  N/A                                N/A                  N/A           N/A       N/A                                                                                   N/A                                                                                                                                                                                      N/A           NO                                                                                                                                                 N/A
# 4     Atalay2020      HIGH  In this paper, we provide an overview of smart grid cybersecurity standards, and review major threats to smart grid environments at the physical, network and application layers. In order to overcome the current lack of standards for security evaluation of smart grids, we propose a digital twins based approach for the complete lifecycle of a smart grid, which accurately models the functioning of the physical grid and avoids service disruptions caused by running security tests on the actual grid.                                                                                                                   At a high level, a digital twin can be de?ned as a virtual replica of an object from the physical world [7]                                                                                                                                                   Generic penetration testing tools are incompetent for this task, as they are generally designed for smaller and more homogeneous networks.      Smart Grid       Penetration Test, Intrusion Detection    Cloud  Smart Meter, Actuator, Network traffic  Physical information devices identi?ers, model, version, storage, input and output size, and location are kept as physical models. On the other hand, the devices have logical pro?les in the system, such as their mapping in the virtual machine, the RAM size, the bandwidth, image size, processing power, etc. A dynamic knowledge database is required in the system, which keeps the logs of monitoring data to model the behavior of a cloudlet. This knowledge database is frequently updated and represents the pro?le of the ecosystem the cloudlet resides in. The database can be organized to store the energy trend information for different times and tasks. Physical models or behavioural models                   DIGITAL_PHYSICAL         DIGITAL_TWIN  TCP/IP, MQTT       N/A         Simulation, Optimization, Machine Learning, Pattern, Outlier, Data Clustering                                                                                                                                                                                      N/A          YES  Our ongoing work includes the modeling and implementation of the proposed security evaluation framework for real-world smart grid infrastructures.

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# ## Identify relevant words defining the Digital Twin

# %%
li_relevance = df_references['Definition'].tolist()


# Get stopwords, stemmer and lemmatizer
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.stem.PorterStemmer()
lemmatizer = nltk.stem.WordNetLemmatizer()

# Remove accents function
def remove_accents(data):
    return ''.join(x for x in unicodedata.normalize('NFKD', data) if x in string.ascii_letters or x == " ")

# Process all quotes
li_tokens = []
li_token_lists = []
li_lem_strings = []

for i,text in enumerate(li_relevance):
    # Tokenize by sentence, then by lowercase word
    if not text:
      text = ''
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]

    # Process all tokens per quote
    li_tokens_quote = []
    li_tokens_quote_lem = []
    for token in tokens:
        # Remove accents
        t = remove_accents(token)

        # Remove punctuation
        t = str(t).translate(string.punctuation)
        li_tokens_quote.append(t)
        
        # Add token that represents "no lemmatization match"
        li_tokens_quote_lem.append("-") # this token will be removed if a lemmatization match is found below

        # Process each token
        if t not in stopwords:
            if re.search(RE_VALID, t):
                if len(t) >= MIN_STR_LEN:
                    # Note that the POS (Part Of Speech) is necessary as input to the lemmatizer 
                    # (otherwise it assumes the word is a noun)
                    pos = nltk.pos_tag([t])[0][1][:2]
                    pos2 = 'n'  # set default to noun
                    if pos in DI_POS_TYPES:
                      pos2 = DI_POS_TYPES[pos]
                    
                    stem = stemmer.stem(t)
                    lem = lemmatizer.lemmatize(t, pos=pos2)  # lemmatize with the correct POS
                    
                    if pos in POS_TYPES:
                        li_tokens.append((t, stem, lem, pos))

                        # Remove the "-" token and append the lemmatization match
                        li_tokens_quote_lem = li_tokens_quote_lem[:-1] 
                        li_tokens_quote_lem.append(lem)

    # Build list of token lists from lemmatized tokens
    li_token_lists.append(li_tokens_quote)
    
    # Build list of strings from lemmatized tokens
    str_li_tokens_quote_lem = ' '.join(li_tokens_quote_lem)
    li_lem_strings.append(str_li_tokens_quote_lem)
    
# Build resulting dataframes from lists
df_token_lists = pd.DataFrame(li_token_lists)


# Replace None with empty string
for c in df_token_lists:
    if str(df_token_lists[c].dtype) in ('object', 'string_', 'unicode_'):
        df_token_lists[c].fillna(value='', inplace=True)

df_lem_strings = pd.DataFrame(li_lem_strings, columns=['lem quote'])


# Add counts
df_all_words = pd.DataFrame(li_tokens, columns=['token', 'stem', 'lem', 'pos'])
df_all_words['counts'] = df_all_words.groupby(['lem'])['lem'].transform('count')
df_all_words = df_all_words.sort_values(by=['counts', 'lem'], ascending=[False, True]).reset_index()

df_words = df_all_words.groupby('lem').first().sort_values(by='counts', ascending=False).reset_index()

df_words = df_words[['lem', 'pos', 'counts']].head(60)
print(df_words)

for v in POS_TYPES:
    df_pos = df_words[df_words['pos'] == v]
 
li_lem_words = df_all_words['lem'].tolist()
di_freq2 = nltk.FreqDist(li_lem_words)
li_freq_sorted2 = sorted(di_freq2.items(), key=lambda x: x[1], reverse=True)  # sorted list
    
di_freq2.plot(30, cumulative=False)
# Out:
#                lem pos  counts
# 0          digital  NN     120
# 1             twin  NN      90
# 2         physical  JJ      77
# 3          virtual  JJ      43
# 4           system  NN      41
# 5             data  NN      33
# 6   representation  NN      27
# 7            model  NN      27
# 8           object  NN      21
# 9           device  NN      19
# 10         product  NN      17
# 11           asset  NN      16
# 12         replica  NN      16
# 13      simulation  NN      16
# 14             use  VB      15
# 15     counterpart  NN      15
# 16         process  NN      14
# 17          entity  NN      13
# 18          mirror  NN      12
# 19       represent  VB      11
# 20           world  NN      11
# 21        behavior  NN      10
# 22          define  VB      10
# 23       realworld  NN      10
# 24            real  JJ       9
# 25        realtime  NN       8
# 26          sensor  NN       7
# 27       lifecycle  NN       7
# 28        security  NN       7
# 29            base  VB       7
# 30        software  NN       7
# 31          enable  JJ       7
# 32      technology  NN       7
# 33     information  NN       7
# 34             dts  NN       6
# 35         connect  VB       6
# 36         context  NN       6
# 37      monitoring  NN       6
# 38        analysis  NN       6
# 39     maintenance  NN       5
# 40            term  NN       5
# 41     environment  NN       5
# 42         include  VB       5
# 43     interaction  NN       5
# 44         service  NN       5
# 45         reflect  NN       5
# 46            life  NN       5
# 47          refers  NN       5
# 48      prediction  NN       5
# 49    continuously  RB       5
# 50            make  VB       5
# 51           level  NN       4
# 52   functionality  NN       4
# 53        simulate  NN       4
# 54         capture  NN       4
# 55      industrial  JJ       4
# 56         history  NN       4
# 57          change  NN       4
# 58            form  NN       4
# 59          expand  NN       4

# %%
# Get stopwords, stemmer and lemmatizer
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.stem.PorterStemmer()
lemmatizer = nltk.stem.WordNetLemmatizer()

# Remove accents function
def remove_accents(data):
    return ''.join(x for x in unicodedata.normalize('NFKD', data) if x in string.ascii_letters or x == " ")

# Process all quotes
li_tokens = []
li_token_lists = []
li_lem_strings = []

for i,word in enumerate(li_lem_words):
    
    word_list = []
    for index, row in df_references.iterrows():
      key = row["Key"]
      definition = row["Definition"]
      tokens = [word.lower() for sent in nltk.sent_tokenize(definition) for word in nltk.word_tokenize(sent)]

      # Process all tokens per quote
      li_tokens_quote = []
      li_tokens_quote_lem = []
      for token in tokens:
        # Remove accents
          t = remove_accents(token)

        # Remove punctuation
          t = str(t).translate(string.punctuation)
          li_tokens_quote.append(t)
        
          # Add token that represents "no lemmatization match"
          li_tokens_quote_lem.append("-") # this token will be removed if a lemmatization match is found below

          # Process each token 
          if t not in stopwords:
              if re.search(RE_VALID, t):
                  if len(t) >= MIN_STR_LEN:
                      # Note that the POS (Part Of Speech) is necessary as input to the lemmatizer 
                      # (otherwise it assumes the word is a noun)
                      pos = nltk.pos_tag([t])[0][1][:2]
                      pos2 = 'n'  # set default to noun
                      if pos in DI_POS_TYPES:
                        pos2 = DI_POS_TYPES[pos]
                    
                      stem = stemmer.stem(t)
                      lem = lemmatizer.lemmatize(t, pos=pos2)  # lemmatize with the correct POS
                       
                      if word == lem:
                        word_list.append(lem)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# fly
# twin
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behaviour
# use
# digital
# tool
# useful
# information
# relates
# physical
# system
# virtualized
# model
# digital
# twin
# online
# digital
# model
# physical
# system
# digital
# replica
# living
# nonliving
# physical
# entity
# digital
# twin
# consists
# two
# part
# digital
# twin
# model
# digital
# twin
# capability
# digital
# twin
# model
# refers
# digital
# representation
# cps
# could
# virtual
# prototype
# cps
# reflect
# partial
# entire
# physical
# process
# mirror
# internal
# behaviour
# physical
# system
# perspective
# autonomous
# vehicle
# digital
# twinrefers
# effort
# place
# design
# implementation
# process
# need
# enhance
# safety
# security
# privacy
# driverless
# car
# dts
# prove
# usefully
# optimise
# system
# base
# collect
# data
# system
# responds
# change
# set
# help
# stakeholder
# realise
# unexploited
# potential
# improve
# operational
# security
# simulation
# also
# fastforwarded
# foresee
# ect
# update
# repair
# preventive
# maintenance
# even
# future
# threat
# high
# level
# digital
# twin
# ned
# virtual
# replica
# object
# physical
# world
# digital
# twin
# define
# evolve
# digital
# profile
# historical
# current
# behavior
# physical
# object
# process
# digital
# twin
# base
# massive
# cumulative
# realtime
# realworld
# data
# measurement
# across
# array
# dimension
# formal
# digital
# representation
# asset
# process
# system
# capture
# attribute
# behavior
# entity
# suitable
# communication
# storage
# interpretation
# processing
# within
# certain
# context
# synthetic
# behavioural
# model
# person
# entity
# use
# predict
# behaviour
# whether
# predict
# drug
# interaction
# medical
# research
# purchasing
# pattern
# online
# shopping
# result
# digital
# twin
# enables
# data
# seamlessly
# transmit
# physical
# virtual
# world
# hence
# ensure
# realtime
# monitoring
# system
# helpful
# maintenance
# future
# upgrade
# even
# possible
# incorporate
# input
# data
# actual
# measurement
# mirror
# operational
# history
# individual
# machine
# know
# digital
# twin
# system
# first
# introduce
# see
# also
# depend
# effort
# spent
# create
# digital
# twin
# realistic
# simulation
# capture
# qualitatively
# correct
# behavior
# machinery
# almost
# perfect
# digital
# copy
# whose
# output
# directly
# compare
# realworld
# machinery
# crucial
# difference
# traditional
# software
# artifact
# use
# composition
# technique
# dts
# dts
# may
# share
# view
# world
# clearly
# consists
# information
# model
# describe
# physical
# twin
# specifically
# consist
# different
# model
# data
# take
# account
# different
# phase
# product
# life
# cycle
# modern
# information
# system
# industrial
# machine
# may
# natively
# come
# indeed
# digital
# twin
# digital
# twin
# virtualdigital
# representation
# physical
# entity
# system
# digital
# twin
# virtual
# replica
# physical
# sensor
# deployed
# farm
# represent
# digital
# twin
# notion
# digital
# twin
# introduce
# nasa
# realistic
# digital
# representation
# fly
# object
# use
# labtesting
# activity
# since
# notion
# also
# adopt
# emerge
# industry
# represent
# status
# production
# device
# enable
# forecast
# change
# impact
# digital
# twin
# idea
# digitally
# represent
# physical
# object
# simulate
# built
# predict
# failure
# enable
# predictive
# maintenance
# cdt
# digital
# representation
# automotive
# software
# author
# arxivv
# cscr
# feb
# department
# head
# firmware
# provide
# many
# advantage
# respect
# automate
# security
# evaluation
# firmware
# term
# digital
# twin
# originally
# define
# virtual
# represeentaion
# manufacture
# various
# lifecycle
# phase
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# combine
# many
# artifical
# intelligence
# base
# rtechnologoies
# method
# realtime
# predictive
# analysis
# forecastign
# algorithm
# preform
# top
# big
# data
# redived
# iot
# sensor
# acquire
# historical
# data
# accomplish
# digital
# twin
# need
# expand
# beyond
# traditional
# model
# simulation
# technique
# incorporate
# sensor
# feedback
# simulation
# feed
# information
# simulation
# back
# physical
# model
# realtime
# generally
# digital
# representation
# realworld
# counterpart
# system
# product
# process
# enterprise
# asset
# lifecycle
# refer
# digital
# twin
# digital
# twin
# comprises
# assetspecific
# data
# typically
# add
# context
# data
# semantic
# technology
# base
# semantically
# link
# data
# analysis
# predictive
# maintenance
# conduct
# general
# refers
# digital
# representation
# realworld
# counterpart
# whole
# lifecycle
# time
# however
# represent
# industrial
# enterprise
# asset
# core
# building
# block
# paradigm
# assetspecific
# data
# item
# often
# enhance
# semantic
# technology
# well
# analysissimulation
# environment
# digitally
# explore
# realworld
# asset
# digital
# twin
# asset
# virtual
# counterpart
# enables
# enterprise
# digitally
# mirror
# manage
# asset
# along
# lifecycle
# asset
# tangible
# well
# nontangible
# range
# turbine
# service
# key
# charactersitcs
# enterprise
# asset
# asset
# lifecycle
# data
# source
# digital
# twin
# semantic
# technology
# data
# analysis
# interface
# asset
# control
# term
# digital
# twin
# coin
# shafto
# describes
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# digital
# twin
# virtual
# replica
# network
# logic
# layer
# physical
# device
# closely
# match
# physical
# device
# behavior
# layer
# term
# digital
# twin
# typically
# refers
# datadriven
# physical
# model
# system
# use
# describe
# emulate
# simulated
# device
# may
# connect
# emulate
# network
# context
# research
# digital
# twin
# reflect
# correct
# behaviour
# physical
# counterpart
# specify
# expert
# industrial
# automation
# domain
# virtual
# replica
# system
# accompanies
# physical
# counterpart
# phase
# lifecycle
# consumes
# realtime
# historical
# data
# require
# sufficient
# fidelity
# allow
# implementation
# desire
# security
# measure
# digital
# twin
# virtually
# replicates
# physical
# counterpart
# ic
# employ
# securityimproving
# use
# case
# digital
# twin
# refers
# simulated
# emulate
# device
# programmable
# logic
# controller
# plc
# connect
# emulate
# network
# concern
# security
# analytics
# service
# security
# module
# digital
# twin
# represent
# link
# realtime
# data
# feasible
# simulation
# forecast
# scenario
# context
# digital
# twin
# therefore
# regard
# foresight
# security
# module
# digital
# twin
# digital
# copy
# obtain
# model
# state
# physical
# system
# collect
# data
# sensor
# place
# system
# reflect
# data
# digital
# medium
# digital
# twin
# build
# bridge
# physical
# digital
# world
# enable
# understand
# past
# present
# process
# make
# prediction
# future
# digital
# twin
# tao
# represent
# digital
# model
# accurately
# mimic
# physical
# counterpart
# evolves
# continuously
# update
# reflect
# change
# physical
# world
# maurer
# becomes
# fertile
# ground
# detect
# deviation
# physical
# twin
# digital
# counterpart
# digital
# twin
# virtual
# representation
# physical
# object
# system
# across
# life
# cycle
# us
# real
# time
# data
# source
# enable
# learn
# reason
# dynamically
# recalibrating
# improve
# decision
# make
# mikell
# clark
# digital
# twin
# digital
# representation
# physical
# object
# process
# system
# exist
# many
# form
# digital
# twin
# human
# context
# data
# footprint
# human
# create
# attribute
# interaction
# attribute
# core
# data
# make
# include
# name
# age
# gender
# address
# ethnicity
# education
# salary
# etc
# interaction
# refers
# data
# footprint
# create
# interact
# external
# world
# term
# digital
# twin
# therefore
# loosely
# apply
# form
# digital
# representation
# digital
# twin
# define
# digital
# replication
# living
# well
# nonliving
# entity
# enable
# data
# seamlessly
# transmit
# physical
# virtual
# world
# computational
# model
# physical
# ssc
# virtual
# replica
# act
# like
# real
# ssc
# assist
# interpretation
# signature
# pattern
# test
# new
# setting
# simulation
# analysis
# type
# scenario
# execution
# whatever
# may
# need
# virtual
# environment
# know
# observe
# would
# also
# arise
# physical
# asset
# scoop
# originally
# concept
# use
# refer
# digital
# representation
# product
# use
# simulation
# software
# expand
# concept
# physical
# product
# represent
# virtual
# form
# software
# product
# directly
# connect
# virtual
# counterpart
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behavior
# use
# digital
# tool
# replicate
# digitize
# physical
# object
# virtual
# space
# simulate
# behavior
# characteristic
# physical
# object
# real
# environment
# digital
# twin
# stand
# software
# replica
# capture
# aspect
# physical
# system
# term
# digital
# twin
# originate
# world
# manufacturing
# digital
# twin
# describe
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# todo
# digital
# twin
# digitalsystem
# connect
# physical
# counterpart
# meant
# mimic
# reality
# great
# possible
# fashion
# meant
# expand
# upon
# humanmachine
# interaction
# integration
# iiot
# industrial
# internet
# thing
# important
# factor
# since
# allows
# extensive
# digital
# knowledge
# physical
# system
# without
# sensor
# connect
# via
# networking
# would
# effective
# compare
# real
# world
# due
# lack
# data
# model
# may
# part
# digital
# representation
# physical
# device
# socalled
# digital
# twin
# instance
# dti
# mirror
# physical
# twin
# entire
# lifespan
# generally
# digital
# twin
# define
# continuously
# adaptive
# model
# complex
# physical
# system
# thus
# significant
# difference
# mathematical
# simulation
# model
# continuous
# adaptability
# alter
# state
# model
# object
# system
# especially
# digital
# twin
# key
# technology
# enhance
# model
# analysis
# prediction
# capability
# argue
# consist
# three
# part
# physical
# associate
# editor
# coordinate
# review
# manuscript
# approve
# publication
# okyay
# kaynak
# product
# digital
# product
# linkage
# physical
# digital
# product
# enables
# real
# time
# communication
# physical
# twin
# direction
# interested
# entity
# process
# system
# read
# data
# physical
# product
# via
# analyze
# data
# execute
# simulation
# exact
# cyber
# copy
# physical
# system
# represent
# functionality
# digital
# twin
# transformative
# technology
# expand
# cps
# digital
# twin
# computation
# module
# even
# visualize
# physical
# process
# digital
# equivalent
# physical
# product
# digital
# twin
# virtual
# representation
# system
# load
# realworld
# input
# environmental
# parameter
# acquire
# realworld
# system
# use
# accurately
# simulate
# realworld
# system
# behavior
# digital
# twin
# digital
# replica
# physical
# system
# able
# mirror
# static
# dynamic
# characteristic
# define
# representation
# physical
# asset
# virtual
# space
# enable
# synchronize
# data
# acquisition
# structure
# functionality
# behavior
# build
# mirror
# integrate
# multiphysics
# physical
# system
# digital
# space
# digital
# twin
# comprehensive
# software
# representation
# individual
# physical
# object
# include
# property
# condition
# behavior
# reallife
# object
# model
# data
# digital
# twin
# set
# realistic
# model
# simulate
# object
# behavior
# deployed
# environment
# digital
# twin
# represent
# reflect
# physical
# twin
# remains
# virtual
# counterpart
# across
# object
# entire
# lifecycle
# digital
# twin
# digital
# replica
# living
# nonliving
# physical
# entity
# coevolves
# entity
# digital
# twin
# traditionally
# thought
# digital
# representation
# virtualized
# prototype
# physical
# system
# digital
# twin
# described
# method
# turn
# physical
# device
# digital
# service
# standard
# defnition
# digital
# twin
# virtual
# replica
# physical
# object
# make
# possible
# monitor
# visualize
# predict
# state
# cyberphysical
# system
# digital
# twin
# virtual
# replica
# cps
# built
# study
# optimize
# design
# deployment
# maintenance
# upgrade
# operation
# digital
# twin
# realistic
# virtual
# representation
# physical
# entity
# digital
# twin
# emerge
# allows
# interaction
# physical
# virtual
# object
# consider
# virtual
# object
# replica
# physical
# object
# allow
# interact
# one
# digital
# twin
# replica
# model
# reside
# virtual
# environment
# include
# everything
# know
# object
# digital
# twin
# define
# virtual
# device
# monitoring
# device
# physical
# entity
# adopt
# factor
# world
# digital
# twin
# digital
# version
# physical
# object
# digital
# twin
# aim
# faithfully
# reproduce
# dynamic
# canal
# digital
# twin
# define
# virtual
# representation
# physical
# asset
# enable
# data
# simulator
# realtime
# prediction
# optimization
# monitoring
# control
# improve
# decision
# make
# digital
# twin
# process
# involves
# creation
# virtual
# model
# twin
# physical
# object
# order
# streamline
# optimize
# maintain
# underlie
# physical
# process
# virtual
# digital
# equivalent
# physical
# product
# set
# virtual
# representation
# enables
# describe
# fundamental
# characteristic
# physical
# entity
# use
# different
# level
# abstraction
# precise
# uptodate
# virtual
# manifestation
# continuously
# aggregate
# data
# come
# physical
# counterpart
# thus
# serve
# central
# knowledge
# base
# realtime
# analysis
# forecasting
# twin
# virtual
# representation
# subsystem
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# digital
# twin
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# base
# literature
# research
# adopt
# definition
# exact
# digital
# replica
# something
# physical
# world
# digital
# twin
# exact
# virtual
# copy
# cyberphysical
# system
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# simplest
# form
# concept
# digital
# twin
# posit
# flow
# data
# process
# decision
# outline
# hypothetical
# scenario
# capture
# software
# avatar
# mimic
# operation
# virtual
# representation
# real
# life
# object
# monitoring
# control
# purpose
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# formalize
# definition
# dts
# integrate
# multiphysics
# multiscale
# probabilistic
# simulation
# mirror
# physical
# system
# base
# model
# sensor
# history
# data
# etc
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# artificial
# intelligence
# system
# model
# often
# refer
# digital
# twin
# digital
# twin
# digital
# representation
# real
# system
# history
# change
# development
# industry
# context
# digital
# twin
# virtual
# representation
# anything
# component
# production
# plant
# product
# assembledmanufactured
# entire
# production
# system
# digital
# twin
# virtual
# representation
# element
# dynamic
# physical
# system
# author
# perspective
# product
# manufacturing
# digital
# twin
# virtual
# representation
# physical
# asset
# counterpart
# connect
# dynamically
# update
# whole
# product
# life
# cycle
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# grief
# defines
# digital
# twin
# set
# virtual
# information
# construct
# fully
# describes
# potential
# actual
# physical
# manufacture
# product
# micro
# atomic
# level
# macro
# geometrical
# level
# shafto
# define
# digital
# twin
# integrate
# multiphysics
# multiscale
# simulation
# vehicle
# system
# us
# best
# available
# physical
# model
# sensor
# update
# fleet
# history
# etc
# mirror
# life
# correspond
# fly
# twin
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behaviour
# use
# digital
# tool
# useful
# information
# relates
# physical
# system
# virtualized
# model
# digital
# twin
# online
# digital
# model
# physical
# system
# digital
# replica
# living
# nonliving
# physical
# entity
# digital
# twin
# consists
# two
# part
# digital
# twin
# model
# digital
# twin
# capability
# digital
# twin
# model
# refers
# digital
# representation
# cps
# could
# virtual
# prototype
# cps
# reflect
# partial
# entire
# physical
# process
# mirror
# internal
# behaviour
# physical
# system
# perspective
# autonomous
# vehicle
# digital
# twinrefers
# effort
# place
# design
# implementation
# process
# need
# enhance
# safety
# security
# privacy
# driverless
# car
# dts
# prove
# usefully
# optimise
# system
# base
# collect
# data
# system
# responds
# change
# set
# help
# stakeholder
# realise
# unexploited
# potential
# improve
# operational
# security
# simulation
# also
# fastforwarded
# foresee
# ect
# update
# repair
# preventive
# maintenance
# even
# future
# threat
# high
# level
# digital
# twin
# ned
# virtual
# replica
# object
# physical
# world
# digital
# twin
# define
# evolve
# digital
# profile
# historical
# current
# behavior
# physical
# object
# process
# digital
# twin
# base
# massive
# cumulative
# realtime
# realworld
# data
# measurement
# across
# array
# dimension
# formal
# digital
# representation
# asset
# process
# system
# capture
# attribute
# behavior
# entity
# suitable
# communication
# storage
# interpretation
# processing
# within
# certain
# context
# synthetic
# behavioural
# model
# person
# entity
# use
# predict
# behaviour
# whether
# predict
# drug
# interaction
# medical
# research
# purchasing
# pattern
# online
# shopping
# result
# digital
# twin
# enables
# data
# seamlessly
# transmit
# physical
# virtual
# world
# hence
# ensure
# realtime
# monitoring
# system
# helpful
# maintenance
# future
# upgrade
# even
# possible
# incorporate
# input
# data
# actual
# measurement
# mirror
# operational
# history
# individual
# machine
# know
# digital
# twin
# system
# first
# introduce
# see
# also
# depend
# effort
# spent
# create
# digital
# twin
# realistic
# simulation
# capture
# qualitatively
# correct
# behavior
# machinery
# almost
# perfect
# digital
# copy
# whose
# output
# directly
# compare
# realworld
# machinery
# crucial
# difference
# traditional
# software
# artifact
# use
# composition
# technique
# dts
# dts
# may
# share
# view
# world
# clearly
# consists
# information
# model
# describe
# physical
# twin
# specifically
# consist
# different
# model
# data
# take
# account
# different
# phase
# product
# life
# cycle
# modern
# information
# system
# industrial
# machine
# may
# natively
# come
# indeed
# digital
# twin
# digital
# twin
# virtualdigital
# representation
# physical
# entity
# system
# digital
# twin
# virtual
# replica
# physical
# sensor
# deployed
# farm
# represent
# digital
# twin
# notion
# digital
# twin
# introduce
# nasa
# realistic
# digital
# representation
# fly
# object
# use
# labtesting
# activity
# since
# notion
# also
# adopt
# emerge
# industry
# represent
# status
# production
# device
# enable
# forecast
# change
# impact
# digital
# twin
# idea
# digitally
# represent
# physical
# object
# simulate
# built
# predict
# failure
# enable
# predictive
# maintenance
# cdt
# digital
# representation
# automotive
# software
# author
# arxivv
# cscr
# feb
# department
# head
# firmware
# provide
# many
# advantage
# respect
# automate
# security
# evaluation
# firmware
# term
# digital
# twin
# originally
# define
# virtual
# represeentaion
# manufacture
# various
# lifecycle
# phase
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# combine
# many
# artifical
# intelligence
# base
# rtechnologoies
# method
# realtime
# predictive
# analysis
# forecastign
# algorithm
# preform
# top
# big
# data
# redived
# iot
# sensor
# acquire
# historical
# data
# accomplish
# digital
# twin
# need
# expand
# beyond
# traditional
# model
# simulation
# technique
# incorporate
# sensor
# feedback
# simulation
# feed
# information
# simulation
# back
# physical
# model
# realtime
# generally
# digital
# representation
# realworld
# counterpart
# system
# product
# process
# enterprise
# asset
# lifecycle
# refer
# digital
# twin
# digital
# twin
# comprises
# assetspecific
# data
# typically
# add
# context
# data
# semantic
# technology
# base
# semantically
# link
# data
# analysis
# predictive
# maintenance
# conduct
# general
# refers
# digital
# representation
# realworld
# counterpart
# whole
# lifecycle
# time
# however
# represent
# industrial
# enterprise
# asset
# core
# building
# block
# paradigm
# assetspecific
# data
# item
# often
# enhance
# semantic
# technology
# well
# analysissimulation
# environment
# digitally
# explore
# realworld
# asset
# digital
# twin
# asset
# virtual
# counterpart
# enables
# enterprise
# digitally
# mirror
# manage
# asset
# along
# lifecycle
# asset
# tangible
# well
# nontangible
# range
# turbine
# service
# key
# charactersitcs
# enterprise
# asset
# asset
# lifecycle
# data
# source
# digital
# twin
# semantic
# technology
# data
# analysis
# interface
# asset
# control
# term
# digital
# twin
# coin
# shafto
# describes
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# digital
# twin
# virtual
# replica
# network
# logic
# layer
# physical
# device
# closely
# match
# physical
# device
# behavior
# layer
# term
# digital
# twin
# typically
# refers
# datadriven
# physical
# model
# system
# use
# describe
# emulate
# simulated
# device
# may
# connect
# emulate
# network
# context
# research
# digital
# twin
# reflect
# correct
# behaviour
# physical
# counterpart
# specify
# expert
# industrial
# automation
# domain
# virtual
# replica
# system
# accompanies
# physical
# counterpart
# phase
# lifecycle
# consumes
# realtime
# historical
# data
# require
# sufficient
# fidelity
# allow
# implementation
# desire
# security
# measure
# digital
# twin
# virtually
# replicates
# physical
# counterpart
# ic
# employ
# securityimproving
# use
# case
# digital
# twin
# refers
# simulated
# emulate
# device
# programmable
# logic
# controller
# plc
# connect
# emulate
# network
# concern
# security
# analytics
# service
# security
# module
# digital
# twin
# represent
# link
# realtime
# data
# feasible
# simulation
# forecast
# scenario
# context
# digital
# twin
# therefore
# regard
# foresight
# security
# module
# digital
# twin
# digital
# copy
# obtain
# model
# state
# physical
# system
# collect
# data
# sensor
# place
# system
# reflect
# data
# digital
# medium
# digital
# twin
# build
# bridge
# physical
# digital
# world
# enable
# understand
# past
# present
# process
# make
# prediction
# future
# digital
# twin
# tao
# represent
# digital
# model
# accurately
# mimic
# physical
# counterpart
# evolves
# continuously
# update
# reflect
# change
# physical
# world
# maurer
# becomes
# fertile
# ground
# detect
# deviation
# physical
# twin
# digital
# counterpart
# digital
# twin
# virtual
# representation
# physical
# object
# system
# across
# life
# cycle
# us
# real
# time
# data
# source
# enable
# learn
# reason
# dynamically
# recalibrating
# improve
# decision
# make
# mikell
# clark
# digital
# twin
# digital
# representation
# physical
# object
# process
# system
# exist
# many
# form
# digital
# twin
# human
# context
# data
# footprint
# human
# create
# attribute
# interaction
# attribute
# core
# data
# make
# include
# name
# age
# gender
# address
# ethnicity
# education
# salary
# etc
# interaction
# refers
# data
# footprint
# create
# interact
# external
# world
# term
# digital
# twin
# therefore
# loosely
# apply
# form
# digital
# representation
# digital
# twin
# define
# digital
# replication
# living
# well
# nonliving
# entity
# enable
# data
# seamlessly
# transmit
# physical
# virtual
# world
# computational
# model
# physical
# ssc
# virtual
# replica
# act
# like
# real
# ssc
# assist
# interpretation
# signature
# pattern
# test
# new
# setting
# simulation
# analysis
# type
# scenario
# execution
# whatever
# may
# need
# virtual
# environment
# know
# observe
# would
# also
# arise
# physical
# asset
# scoop
# originally
# concept
# use
# refer
# digital
# representation
# product
# use
# simulation
# software
# expand
# concept
# physical
# product
# represent
# virtual
# form
# software
# product
# directly
# connect
# virtual
# counterpart
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behavior
# use
# digital
# tool
# replicate
# digitize
# physical
# object
# virtual
# space
# simulate
# behavior
# characteristic
# physical
# object
# real
# environment
# digital
# twin
# stand
# software
# replica
# capture
# aspect
# physical
# system
# term
# digital
# twin
# originate
# world
# manufacturing
# digital
# twin
# describe
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# todo
# digital
# twin
# digitalsystem
# connect
# physical
# counterpart
# meant
# mimic
# reality
# great
# possible
# fashion
# meant
# expand
# upon
# humanmachine
# interaction
# integration
# iiot
# industrial
# internet
# thing
# important
# factor
# since
# allows
# extensive
# digital
# knowledge
# physical
# system
# without
# sensor
# connect
# via
# networking
# would
# effective
# compare
# real
# world
# due
# lack
# data
# model
# may
# part
# digital
# representation
# physical
# device
# socalled
# digital
# twin
# instance
# dti
# mirror
# physical
# twin
# entire
# lifespan
# generally
# digital
# twin
# define
# continuously
# adaptive
# model
# complex
# physical
# system
# thus
# significant
# difference
# mathematical
# simulation
# model
# continuous
# adaptability
# alter
# state
# model
# object
# system
# especially
# digital
# twin
# key
# technology
# enhance
# model
# analysis
# prediction
# capability
# argue
# consist
# three
# part
# physical
# associate
# editor
# coordinate
# review
# manuscript
# approve
# publication
# okyay
# kaynak
# product
# digital
# product
# linkage
# physical
# digital
# product
# enables
# real
# time
# communication
# physical
# twin
# direction
# interested
# entity
# process
# system
# read
# data
# physical
# product
# via
# analyze
# data
# execute
# simulation
# exact
# cyber
# copy
# physical
# system
# represent
# functionality
# digital
# twin
# transformative
# technology
# expand
# cps
# digital
# twin
# computation
# module
# even
# visualize
# physical
# process
# digital
# equivalent
# physical
# product
# digital
# twin
# virtual
# representation
# system
# load
# realworld
# input
# environmental
# parameter
# acquire
# realworld
# system
# use
# accurately
# simulate
# realworld
# system
# behavior
# digital
# twin
# digital
# replica
# physical
# system
# able
# mirror
# static
# dynamic
# characteristic
# define
# representation
# physical
# asset
# virtual
# space
# enable
# synchronize
# data
# acquisition
# structure
# functionality
# behavior
# build
# mirror
# integrate
# multiphysics
# physical
# system
# digital
# space
# digital
# twin
# comprehensive
# software
# representation
# individual
# physical
# object
# include
# property
# condition
# behavior
# reallife
# object
# model
# data
# digital
# twin
# set
# realistic
# model
# simulate
# object
# behavior
# deployed
# environment
# digital
# twin
# represent
# reflect
# physical
# twin
# remains
# virtual
# counterpart
# across
# object
# entire
# lifecycle
# digital
# twin
# digital
# replica
# living
# nonliving
# physical
# entity
# coevolves
# entity
# digital
# twin
# traditionally
# thought
# digital
# representation
# virtualized
# prototype
# physical
# system
# digital
# twin
# described
# method
# turn
# physical
# device
# digital
# service
# standard
# defnition
# digital
# twin
# virtual
# replica
# physical
# object
# make
# possible
# monitor
# visualize
# predict
# state
# cyberphysical
# system
# digital
# twin
# virtual
# replica
# cps
# built
# study
# optimize
# design
# deployment
# maintenance
# upgrade
# operation
# digital
# twin
# realistic
# virtual
# representation
# physical
# entity
# digital
# twin
# emerge
# allows
# interaction
# physical
# virtual
# object
# consider
# virtual
# object
# replica
# physical
# object
# allow
# interact
# one
# digital
# twin
# replica
# model
# reside
# virtual
# environment
# include
# everything
# know
# object
# digital
# twin
# define
# virtual
# device
# monitoring
# device
# physical
# entity
# adopt
# factor
# world
# digital
# twin
# digital
# version
# physical
# object
# digital
# twin
# aim
# faithfully
# reproduce
# dynamic
# canal
# digital
# twin
# define
# virtual
# representation
# physical
# asset
# enable
# data
# simulator
# realtime
# prediction
# optimization
# monitoring
# control
# improve
# decision
# make
# digital
# twin
# process
# involves
# creation
# virtual
# model
# twin
# physical
# object
# order
# streamline
# optimize
# maintain
# underlie
# physical
# process
# virtual
# digital
# equivalent
# physical
# product
# set
# virtual
# representation
# enables
# describe
# fundamental
# characteristic
# physical
# entity
# use
# different
# level
# abstraction
# precise
# uptodate
# virtual
# manifestation
# continuously
# aggregate
# data
# come
# physical
# counterpart
# thus
# serve
# central
# knowledge
# base
# realtime
# analysis
# forecasting
# twin
# virtual
# representation
# subsystem
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# digital
# twin
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# base
# literature
# research
# adopt
# definition
# exact
# digital
# replica
# something
# physical
# world
# digital
# twin
# exact
# virtual
# copy
# cyberphysical
# system
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# simplest
# form
# concept
# digital
# twin
# posit
# flow
# data
# process
# decision
# outline
# hypothetical
# scenario
# capture
# software
# avatar
# mimic
# operation
# virtual
# representation
# real
# life
# object
# monitoring
# control
# purpose
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# formalize
# definition
# dts
# integrate
# multiphysics
# multiscale
# probabilistic
# simulation
# mirror
# physical
# system
# base
# model
# sensor
# history
# data
# etc
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# artificial
# intelligence
# system
# model
# often
# refer
# digital
# twin
# digital
# twin
# digital
# representation
# real
# system
# history
# change
# development
# industry
# context
# digital
# twin
# virtual
# representation
# anything
# component
# production
# plant
# product
# assembledmanufactured
# entire
# production
# system
# digital
# twin
# virtual
# representation
# element
# dynamic
# physical
# system
# author
# perspective
# product
# manufacturing
# digital
# twin
# virtual
# representation
# physical
# asset
# counterpart
# connect
# dynamically
# update
# whole
# product
# life
# cycle
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# grief
# defines
# digital
# twin
# set
# virtual
# information
# construct
# fully
# describes
# potential
# actual
# physical
# manufacture
# product
# micro
# atomic
# level
# macro
# geometrical
# level
# shafto
# define
# digital
# twin
# integrate
# multiphysics
# multiscale
# simulation
# vehicle
# system
# us
# best
# available
# physical
# model
# sensor
# update
# fleet
# history
# etc
# mirror
# life
# correspond
# fly
# twin
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behaviour
# use
# digital
# tool
# useful
# information
# relates
# physical
# system
# virtualized
# model
# digital
# twin
# online
# digital
# model
# physical
# system
# digital
# replica
# living
# nonliving
# physical
# entity
# digital
# twin
# consists
# two
# part
# digital
# twin
# model
# digital
# twin
# capability
# digital
# twin
# model
# refers
# digital
# representation
# cps
# could
# virtual
# prototype
# cps
# reflect
# partial
# entire
# physical
# process
# mirror
# internal
# behaviour
# physical
# system
# perspective
# autonomous
# vehicle
# digital
# twinrefers
# effort
# place
# design
# implementation
# process
# need
# enhance
# safety
# security
# privacy
# driverless
# car
# dts
# prove
# usefully
# optimise
# system
# base
# collect
# data
# system
# responds
# change
# set
# help
# stakeholder
# realise
# unexploited
# potential
# improve
# operational
# security
# simulation
# also
# fastforwarded
# foresee
# ect
# update
# repair
# preventive
# maintenance
# even
# future
# threat
# high
# level
# digital
# twin
# ned
# virtual
# replica
# object
# physical
# world
# digital
# twin
# define
# evolve
# digital
# profile
# historical
# current
# behavior
# physical
# object
# process
# digital
# twin
# base
# massive
# cumulative
# realtime
# realworld
# data
# measurement
# across
# array
# dimension
# formal
# digital
# representation
# asset
# process
# system
# capture
# attribute
# behavior
# entity
# suitable
# communication
# storage
# interpretation
# processing
# within
# certain
# context
# synthetic
# behavioural
# model
# person
# entity
# use
# predict
# behaviour
# whether
# predict
# drug
# interaction
# medical
# research
# purchasing
# pattern
# online
# shopping
# result
# digital
# twin
# enables
# data
# seamlessly
# transmit
# physical
# virtual
# world
# hence
# ensure
# realtime
# monitoring
# system
# helpful
# maintenance
# future
# upgrade
# even
# possible
# incorporate
# input
# data
# actual
# measurement
# mirror
# operational
# history
# individual
# machine
# know
# digital
# twin
# system
# first
# introduce
# see
# also
# depend
# effort
# spent
# create
# digital
# twin
# realistic
# simulation
# capture
# qualitatively
# correct
# behavior
# machinery
# almost
# perfect
# digital
# copy
# whose
# output
# directly
# compare
# realworld
# machinery
# crucial
# difference
# traditional
# software
# artifact
# use
# composition
# technique
# dts
# dts
# may
# share
# view
# world
# clearly
# consists
# information
# model
# describe
# physical
# twin
# specifically
# consist
# different
# model
# data
# take
# account
# different
# phase
# product
# life
# cycle
# modern
# information
# system
# industrial
# machine
# may
# natively
# come
# indeed
# digital
# twin
# digital
# twin
# virtualdigital
# representation
# physical
# entity
# system
# digital
# twin
# virtual
# replica
# physical
# sensor
# deployed
# farm
# represent
# digital
# twin
# notion
# digital
# twin
# introduce
# nasa
# realistic
# digital
# representation
# fly
# object
# use
# labtesting
# activity
# since
# notion
# also
# adopt
# emerge
# industry
# represent
# status
# production
# device
# enable
# forecast
# change
# impact
# digital
# twin
# idea
# digitally
# represent
# physical
# object
# simulate
# built
# predict
# failure
# enable
# predictive
# maintenance
# cdt
# digital
# representation
# automotive
# software
# author
# arxivv
# cscr
# feb
# department
# head
# firmware
# provide
# many
# advantage
# respect
# automate
# security
# evaluation
# firmware
# term
# digital
# twin
# originally
# define
# virtual
# represeentaion
# manufacture
# various
# lifecycle
# phase
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# combine
# many
# artifical
# intelligence
# base
# rtechnologoies
# method
# realtime
# predictive
# analysis
# forecastign
# algorithm
# preform
# top
# big
# data
# redived
# iot
# sensor
# acquire
# historical
# data
# accomplish
# digital
# twin
# need
# expand
# beyond
# traditional
# model
# simulation
# technique
# incorporate
# sensor
# feedback
# simulation
# feed
# information
# simulation
# back
# physical
# model
# realtime
# generally
# digital
# representation
# realworld
# counterpart
# system
# product
# process
# enterprise
# asset
# lifecycle
# refer
# digital
# twin
# digital
# twin
# comprises
# assetspecific
# data
# typically
# add
# context
# data
# semantic
# technology
# base
# semantically
# link
# data
# analysis
# predictive
# maintenance
# conduct
# general
# refers
# digital
# representation
# realworld
# counterpart
# whole
# lifecycle
# time
# however
# represent
# industrial
# enterprise
# asset
# core
# building
# block
# paradigm
# assetspecific
# data
# item
# often
# enhance
# semantic
# technology
# well
# analysissimulation
# environment
# digitally
# explore
# realworld
# asset
# digital
# twin
# asset
# virtual
# counterpart
# enables
# enterprise
# digitally
# mirror
# manage
# asset
# along
# lifecycle
# asset
# tangible
# well
# nontangible
# range
# turbine
# service
# key
# charactersitcs
# enterprise
# asset
# asset
# lifecycle
# data
# source
# digital
# twin
# semantic
# technology
# data
# analysis
# interface
# asset
# control
# term
# digital
# twin
# coin
# shafto
# describes
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# digital
# twin
# virtual
# replica
# network
# logic
# layer
# physical
# device
# closely
# match
# physical
# device
# behavior
# layer
# term
# digital
# twin
# typically
# refers
# datadriven
# physical
# model
# system
# use
# describe
# emulate
# simulated
# device
# may
# connect
# emulate
# network
# context
# research
# digital
# twin
# reflect
# correct
# behaviour
# physical
# counterpart
# specify
# expert
# industrial
# automation
# domain
# virtual
# replica
# system
# accompanies
# physical
# counterpart
# phase
# lifecycle
# consumes
# realtime
# historical
# data
# require
# sufficient
# fidelity
# allow
# implementation
# desire
# security
# measure
# digital
# twin
# virtually
# replicates
# physical
# counterpart
# ic
# employ
# securityimproving
# use
# case
# digital
# twin
# refers
# simulated
# emulate
# device
# programmable
# logic
# controller
# plc
# connect
# emulate
# network
# concern
# security
# analytics
# service
# security
# module
# digital
# twin
# represent
# link
# realtime
# data
# feasible
# simulation
# forecast
# scenario
# context
# digital
# twin
# therefore
# regard
# foresight
# security
# module
# digital
# twin
# digital
# copy
# obtain
# model
# state
# physical
# system
# collect
# data
# sensor
# place
# system
# reflect
# data
# digital
# medium
# digital
# twin
# build
# bridge
# physical
# digital
# world
# enable
# understand
# past
# present
# process
# make
# prediction
# future
# digital
# twin
# tao
# represent
# digital
# model
# accurately
# mimic
# physical
# counterpart
# evolves
# continuously
# update
# reflect
# change
# physical
# world
# maurer
# becomes
# fertile
# ground
# detect
# deviation
# physical
# twin
# digital
# counterpart
# digital
# twin
# virtual
# representation
# physical
# object
# system
# across
# life
# cycle
# us
# real
# time
# data
# source
# enable
# learn
# reason
# dynamically
# recalibrating
# improve
# decision
# make
# mikell
# clark
# digital
# twin
# digital
# representation
# physical
# object
# process
# system
# exist
# many
# form
# digital
# twin
# human
# context
# data
# footprint
# human
# create
# attribute
# interaction
# attribute
# core
# data
# make
# include
# name
# age
# gender
# address
# ethnicity
# education
# salary
# etc
# interaction
# refers
# data
# footprint
# create
# interact
# external
# world
# term
# digital
# twin
# therefore
# loosely
# apply
# form
# digital
# representation
# digital
# twin
# define
# digital
# replication
# living
# well
# nonliving
# entity
# enable
# data
# seamlessly
# transmit
# physical
# virtual
# world
# computational
# model
# physical
# ssc
# virtual
# replica
# act
# like
# real
# ssc
# assist
# interpretation
# signature
# pattern
# test
# new
# setting
# simulation
# analysis
# type
# scenario
# execution
# whatever
# may
# need
# virtual
# environment
# know
# observe
# would
# also
# arise
# physical
# asset
# scoop
# originally
# concept
# use
# refer
# digital
# representation
# product
# use
# simulation
# software
# expand
# concept
# physical
# product
# represent
# virtual
# form
# software
# product
# directly
# connect
# virtual
# counterpart
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behavior
# use
# digital
# tool
# replicate
# digitize
# physical
# object
# virtual
# space
# simulate
# behavior
# characteristic
# physical
# object
# real
# environment
# digital
# twin
# stand
# software
# replica
# capture
# aspect
# physical
# system
# term
# digital
# twin
# originate
# world
# manufacturing
# digital
# twin
# describe
# use
# holistic
# simulation
# virtually
# mirror
# physical
# system
# todo
# digital
# twin
# digitalsystem
# connect
# physical
# counterpart
# meant
# mimic
# reality
# great
# possible
# fashion
# meant
# expand
# upon
# humanmachine
# interaction
# integration
# iiot
# industrial
# internet
# thing
# important
# factor
# since
# allows
# extensive
# digital
# knowledge
# physical
# system
# without
# sensor
# connect
# via
# networking
# would
# effective
# compare
# real
# world
# due
# lack
# data
# model
# may
# part
# digital
# representation
# physical
# device
# socalled
# digital
# twin
# instance
# dti
# mirror
# physical
# twin
# entire
# lifespan
# generally
# digital
# twin
# define
# continuously
# adaptive
# model
# complex
# physical
# system
# thus
# significant
# difference
# mathematical
# simulation
# model
# continuous
# adaptability
# alter
# state
# model
# object
# system
# especially
# digital
# twin
# key
# technology
# enhance
# model
# analysis
# prediction
# capability
# argue
# consist
# three
# part
# physical
# associate
# editor
# coordinate
# review
# manuscript
# approve
# publication
# okyay
# kaynak
# product
# digital
# product
# linkage
# physical
# digital
# product
# enables
# real
# time
# communication
# physical
# twin
# direction
# interested
# entity
# process
# system
# read
# data
# physical
# product
# via
# analyze
# data
# execute
# simulation
# exact
# cyber
# copy
# physical
# system
# represent
# functionality
# digital
# twin
# transformative
# technology
# expand
# cps
# digital
# twin
# computation
# module
# even
# visualize
# physical
# process
# digital
# equivalent
# physical
# product
# digital
# twin
# virtual
# representation
# system
# load
# realworld
# input
# environmental
# parameter
# acquire
# realworld
# system
# use
# accurately
# simulate
# realworld
# system
# behavior
# digital
# twin
# digital
# replica
# physical
# system
# able
# mirror
# static
# dynamic
# characteristic
# define
# representation
# physical
# asset
# virtual
# space
# enable
# synchronize
# data
# acquisition
# structure
# functionality
# behavior
# build
# mirror
# integrate
# multiphysics
# physical
# system
# digital
# space
# digital
# twin
# comprehensive
# software
# representation
# individual
# physical
# object
# include
# property
# condition
# behavior
# reallife
# object
# model
# data
# digital
# twin
# set
# realistic
# model
# simulate
# object
# behavior
# deployed
# environment
# digital
# twin
# represent
# reflect
# physical
# twin
# remains
# virtual
# counterpart
# across
# object
# entire
# lifecycle
# digital
# twin
# digital
# replica
# living
# nonliving
# physical
# entity
# coevolves
# entity
# digital
# twin
# traditionally
# thought
# digital
# representation
# virtualized
# prototype
# physical
# system
# digital
# twin
# described
# method
# turn
# physical
# device
# digital
# service
# standard
# defnition
# digital
# twin
# virtual
# replica
# physical
# object
# make
# possible
# monitor
# visualize
# predict
# state
# cyberphysical
# system
# digital
# twin
# virtual
# replica
# cps
# built
# study
# optimize
# design
# deployment
# maintenance
# upgrade
# operation
# digital
# twin
# realistic
# virtual
# representation
# physical
# entity
# digital
# twin
# emerge
# allows
# interaction
# physical
# virtual
# object
# consider
# virtual
# object
# replica
# physical
# object
# allow
# interact
# one
# digital
# twin
# replica
# model
# reside
# virtual
# environment
# include
# everything
# know
# object
# digital
# twin
# define
# virtual
# device
# monitoring
# device
# physical
# entity
# adopt
# factor
# world
# digital
# twin
# digital
# version
# physical
# object
# digital
# twin
# aim
# faithfully
# reproduce
# dynamic
# canal
# digital
# twin
# define
# virtual
# representation
# physical
# asset
# enable
# data
# simulator
# realtime
# prediction
# optimization
# monitoring
# control
# improve
# decision
# make
# digital
# twin
# process
# involves
# creation
# virtual
# model
# twin
# physical
# object
# order
# streamline
# optimize
# maintain
# underlie
# physical
# process
# virtual
# digital
# equivalent
# physical
# product
# set
# virtual
# representation
# enables
# describe
# fundamental
# characteristic
# physical
# entity
# use
# different
# level
# abstraction
# precise
# uptodate
# virtual
# manifestation
# continuously
# aggregate
# data
# come
# physical
# counterpart
# thus
# serve
# central
# knowledge
# base
# realtime
# analysis
# forecasting
# twin
# virtual
# representation
# subsystem
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# digital
# twin
# define
# digital
# replicamodel
# include
# last
# information
# match
# thing
# base
# literature
# research
# adopt
# definition
# exact
# digital
# replica
# something
# physical
# world
# digital
# twin
# exact
# virtual
# copy
# cyberphysical
# system
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# digital
# twin
# virtual
# representation
# device
# group
# device
# resides
# cloud
# edge
# node
# use
# represent
# realworld
# device
# may
# continuously
# online
# run
# simulation
# new
# application
# service
# get
# deployed
# real
# device
# simplest
# form
# concept
# digital
# twin
# posit
# flow
# data
# process
# decision
# outline
# hypothetical
# scenario
# capture
# software
# avatar
# mimic
# operation
# virtual
# representation
# real
# life
# object
# monitoring
# control
# purpose
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# formalize
# definition
# dts
# integrate
# multiphysics
# multiscale
# probabilistic
# simulation
# mirror
# physical
# system
# base
# model
# sensor
# history
# data
# etc
# dts
# virtual
# replica
# physical
# system
# mirror
# every
# facet
# product
# process
# provide
# actionable
# insight
# monitoring
# optimization
# prediction
# artificial
# intelligence
# system
# model
# often
# refer
# digital
# twin
# digital
# twin
# digital
# representation
# real
# system
# history
# change
# development
# industry
# context
# digital
# twin
# virtual
# representation
# anything
# component
# production
# plant
# product
# assembledmanufactured
# entire
# production
# system
# digital
# twin
# virtual
# representation
# element
# dynamic
# physical
# system
# author
# perspective
# product
# manufacturing
# digital
# twin
# virtual
# representation
# physical
# asset
# counterpart
# connect
# dynamically
# update
# whole
# product
# life
# cycle
# digital
# twin
# virtual
# counterpart
# actual
# physical
# device
# entity
# grief
# defines
# digital
# twin
# set
# virtual
# information
# construct
# fully
# describes
# potential
# actual
# physical
# manufacture
# product
# micro
# atomic
# level
# macro
# geometrical
# level
# shafto
# define
# digital
# twin
# integrate
# multiphysics
# multiscale
# simulation
# vehicle
# system
# us
# best
# available
# physical
# model
# sensor
# update
# fleet
# history
# etc
# mirror
# life
# correspond
# fly
# twin
# digital
# twin
# technology
# model
# asset
# geometrical
# data
# kinematic
# functionality
# logical
# behaviour
# use
# digital
# tool
# useful
# information
# relates
# physical
# system
# virtualized
# model
# digital
# twin
# online
# digital
# model
# physical
# system
# digital
# replica
# living
# nonliving
# physical
# entity
# digital
# twin
# consists
# two
# part
# digital
# twin
# model
# digital
# twin
# capability
# digital
# twin
# model
# refers
# digital
# representation
# cps
# could
# virtual
# prototype
# cps
# reflect
# partial
# entire
# physical
# process
# mirror
# internal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-5bebf310e8e8> in <module>()
#      40                       # Note that the POS (Part Of Speech) is necessary as input to the lemmatizer
#      41                       # (otherwise it assumes the word is a noun)
# ---> 42                       pos = nltk.pos_tag([t])[0][1][:2]
#      43                       pos2 = 'n'  # set default to noun
#      44                       if pos in DI_POS_TYPES:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     132     """
#     133     tagger = _get_tagger(lang)
# --> 134     return _pos_tag(tokens, tagset, tagger)
#     135
#     136
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger)
#     100
#     101 def _pos_tag(tokens, tagset, tagger):
# --> 102     tagged_tokens = tagger.tag(tokens)
#     103     if tagset:
#     104         tagged_tokens = [(token, map_tag('en-ptb', tagset, tag)) for (token, tag) in tagged_tokens]
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/perceptron.py in tag(self, tokens)
#     155             if not tag:
#     156                 features = self._get_features(i, word, context, prev, prev2)
# --> 157                 tag = self.model.predict(features)
#     158             output.append((word, tag))
#     159             prev2 = prev
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/perceptron.py in predict(self, features)
#      54             weights = self.weights[feat]
#      55             for label, weight in weights.items():
# ---> 56                 scores[label] += value * weight
#      57         # Do a secondary alphabetic sort, for stability
#      58         return max(self.classes, key=lambda label: (scores[label], label))
#
# KeyboardInterrupt:

# %% [markdown]
# ```
# # Als Code formatiert
# ```
#
# ## Identify relevant words

# %%
data = []
 
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
 
# show plot
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

definition_list = df_references['Definition'].tolist()
definition_string = " ".join(str(x) for x in definition_list)

# change this to read in your data
finder = BigramCollocationFinder.from_words(definition_string)

# only bigrams that appear 3+ times
finder.apply_freq_filter(10)

# return the 10 n-grams with the highest PMI
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('N', '/'),
#  ('/', 'A'),
#  ('b', 'j'),
#  (']', '.'),
#  ('D', 'T'),
#  ('T', 'w'),
#  ('-', 'w'),
#  ('l', '-'),
#  ('i', 'z'),
#  ('j', 'e')]
